# %% [markdown]
# ### Introduction
#      Audience
#
#      DATA SOURCE
#      making of (first version)
#
#      redesigned: original vs final
#      why is it a good redesign
#
#      deception : original vs final
#      why is it a good deception
#
#      Data cleaning
#
#      links : python notebook, tableau public, screenshots
#
#      Claim , data , warrantr, backing, rebuttal
#
#      Goal, question ,metric
#      perception, comprehension, projection

# %% [markdown]
# ## MSIS 2629: Dashboards, Scorecard, and Visualization
# ### INDIVIDUAL PROJECT : REVISED VERSIONS
# ### AUTHOR : SALONI SHARMA
# **_____________________________________________________________________________________________________________________**

# %% [markdown]
# ### PREFACE :
#
# In this project, I take the graphs given in the [Vox article](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) **"America’s unique gun violence problem, explained in 17 maps and charts"** and attempt to substantially improve them as well as my previous versions.

# %% [markdown]
# ### INTRODUCTION :
#
# America is facing a gun violence problem and this holds true, even without collecting any facts, as seen from the shootings that have occurred in the past few months itself.
#
# The Vox article tries to analyze the gun-violence problem of the USA using graphs and charts, developed through data-sets obtained from various different sources.
#
# For my analysis, I have picked the first three graphs of the article.
#
# The graphs and their basic summary are as follows:
#
# Graph 1: Number of firearm homicides
# > The first graph compares the number of firearm homicides in the USA with the rest of the world.
#
# Graph 2: Number of civilian-owned guns compared to the population
# > The second graph compares the population and the number of civilian-owned guns in the USA with other countries of the world.
#
# Graph 3: Mass Shootings
# > The third graph shows the change in the number of mass shootings in the USA since the Sandy Hook shooting in Dec 2012.
#
# My audience for this project would be the **General Public** or the common US population because I think it is the general public that needs to think and understand the implications of the wide and easy availability of firearms and their consequences.

# %% [markdown]
# ### GRAPH 1:
#
# #### 1.1 Article View :
# The point the [article](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) makes for the 1st graph is : *"America has six times as many firearm homicides as Canada, and nearly 16 times as many as Germany"*.
# It states that America leads the developed countries when it comes to firearm homicides.
#
# The graph from the article is as follows :

# %% [markdown]
# ##put screenshot

# %% [markdown]
# #### 1.2 MY VIEW :
#
# According to me , the human-figurine format of the graph could put the point forward in a better way if a bar chart was used instead.
#
# **Data Source** : The data source is [this](https://docs.google.com/spreadsheets/d/1chqUZHuY6cXYrRYkuE0uwXisGaYvr7durZHJhpLGycs/edit#gid=0)
#
# #### 1.2.1. REDESIGN VERSION
# My goal with the redesign is make the original graph look better, and to show that America owns a huge amount of guns compared to the other countries in the world.
#
# The metrics I have used is the data of the different countries that I have from the dataset mentioned above.
#
# **First Version:** My first attempt to redesign the orginal visualization is as follows:
#
# ##put screen shot
#
# **Revised Version:** I improved upon the first version of the redesigned visualization shown above and redesigned it..I took the 14 countries included in the original visualization in the Vox article and compared them with each other.
#
# The revised version of the redeisgn can be seen [here]() ##put screen shot and link

# %% [markdown]
# As it can be seen, the claim I am trying to make through the above graph is that- The USA has extremely high number of civilian owned firearms amongst the developed countries in the world.
# My backing and warrant come from the data source.
# My hypothesis is that the comparison is only between the developed nations in the world and not *all* the countries in the world.
#
# My redesigned visualization supports my above-mentioned claim.

# %% [markdown]
# A comparison between the original Vox article graph and my redesiged version is as follows : ##put screenshots

# %% [markdown]
# **Data Cleaning:** The process I took to clean the data obtained from the data source is [here]() ##put link

# %% [markdown]
# #### 1.2.2 DECEPTIVE VERSION:
#
# My goal with the deceptive version was to show that USA is *not* an outlier when it comes to firearm homicides, and that there are other countries in the world that precede it.
#
# My metric for this was the dataset that I found while cleaning the dataset for the redesigned version.
#
# **First Version:** My first attempt to develop a deceptive visualization is as follows:
#  ##put screenshot
#
# **Revised Version:** When I developed the ‘Redesign’ version of this chart, I found that in reality, USA is preceded by 4 other countries - Brazil, Colombia, Mexico and Venezuela in the number the firearm homicides. This graph shows the actual view of the situation each country of the world is in, in terms of firearm homicides.  It shows that USA is *not* the country with the highest number of firearm homicides in the world, like how the article implies. Brazil far exceeds the USA in this scenario.
#
# The revised version of the redesign can be seen [here]()
#
# *put screenshot and link *
#
# As it can be seen, the claim I am trying to make through the above graph is that- The USA is *not* a country with the highest number of firearm homicides. In terms of being an outlier, it is Brazil who takes the 1st place , and not USA.
#
# My backing and warrant come from the data source.
#
# My hypothesis and rebuttal is that the comparison is now between all the countries of the world. There are many countries that have extremely strict guns laws, whereas there are very few/liberal laws regarding guns and gun-ownership in few other countries. Other factors like how well developed a country is also affects the number of people who own guns.This graph is a good visual to get an overall picture of the firearm homicide scenario, but putting countries into certain bins would help us understand this situation better.
#
# My deceptive visualization supports my above-mentioned claim.
#
# A comparison between the original Vox article graph and my deceptive version is as follows : ##put screenshots
#
# **Data Cleaning:** The process I took to clean the data obtained from the data source is [here]() ##put link

# %% [markdown]
# ### GRAPH 2 :
#
# #### 2.1 Article View :
# The point the [article](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) makes for the 1st graph is : *"America has 4.4 percent of the world’s population, but almost half of the civilian-owned guns around the world"*.
#
# The graph from the article is as follows :
#
# ##put screenshot
#
# #### 2.2 MY VIEW :
# The graph looks good but then, it does not make much sense, especially because the values are given in terms of percentages.
# In order to understand what the graph actually means, I did some calculations of my own, as follows -
#
# For the left hand side of the Graph : Population of the world
# * Population of the US = 4.43% of 7.13 Billion = 31.58 * 10^7
#
# For the right hand side of the Graph : Civilian owned guns in the world
# * Civilian owned guns in the US = 42% of 644 Million = 27.048 * 10^7
#
# From this, I calculated the percent of US population that owns guns :
# * Percent of Civilian owned guns = (Civilian owned guns in the USA / Population of the USA) * 100
# * Percent of Civilina owned guns = 85.6%
#
# **85.6% of US population owns guns. **
#
# So this is what the graph was trying to put forth. Noted!
#
#
# **Data Source** : The data source is [this](https://photius.com/rankings/population/population_2007_0.html) and [this](https://docs.google.com/spreadsheets/d/1chqUZHuY6cXYrRYkuE0uwXisGaYvr7durZHJhpLGycs/edit#gid=0).
#
# #### 2.2.1. REDESIGN VERSION
# My goal with the redesign is to show that almost 85% of the population of the USA owns guns.
#
# The metrics I have used is the dataset from the source mentioned above.
#
#
# **First Version:** My first attempt to redesign the orginal visualization is as follows:
#
# ##put screen shot
#
# **Revised Version:** I improved upon the first version of the redesigned visualization shown above and redesigned it I have compared the two entities - the population and the number of civilian owned guns.
#
# I came up with 3 different redesign versions :
#
# 1. This graph compares the population and civilian owned firearms only in the USA. The heights of these bar graphs are very close to each other, showing that more than 50% of the population of the USA owns guns, which just means that way too many people have firearms in this country, which is a bad news in itself, considering how gun violence is on the incease as days go by. For this, I selected to keep only 'USA' in the Tableau worksheet.
# 2. This graph shows the comparison between USA and the rest of the countries in the world in terms of population and civilian owned firearms.
# 3. This version is my Final Redesign version:
#
# This graph effectively shows how high the percentage of firearm the USA has compared to the rest of the coutnries in the world. For ease, I have visualized only the top 10 countries with a high percentage of Civilian owned firearm to Total population ratio.
#
#
# The final revised version of the redeisgn can be seen [here]() ##put screen shot and link
#
# As it can be seen, the claim I am trying to make through the above graph is that- More than 85% of the US population owns guns. This is far too more when compared to the rest of the countries.
# My backing and warrant come from the data source.
#
# My redesigned visualization supports my above-mentioned claim.
#
# A comparison between the original Vox article graph and my redesiged version is as follows : ##put screenshots
#
# **Data Cleaning:** For this visual, I used 2 datasets.  The dataset from [Photius] ( https://photius.com/rankings/population/population_2007_0.html ) had to be first copied and pasted into notepad, from where I opened it in Excel selecting the "Delimited" and "Tab" as my criterias. Once the data opened in Excel, I gave the headers to the last 2 columns as “Country” and “Population” so that the analysis could become easier. The next steps of cleaning the data of the Excel file can be found [here]() ##put link

# %% [markdown]
# #### 2.2.2 DECEPTIVE VERSION:
#
# My goal with the deceptive version was to show that USA does not have that many guns compared to the population.
#
#
# **First Version:** My first attempt to develop a deceptive visualization is as follows:
#  ##put screenshot
#
# **Revised Version:** My revised version is the same as the first version because it deceipts the audience into thinking that the number of firearms in the USA are not that many compared to the population.
#
# I developed a side-by-side bar chart to show the population and the average number of civilian owned firearms next to each other. What this does is that the Y axis has only 1 scale for the range, and because the actual total population is of the USA is more than the number of average number of civilian owned guns, it provides a counter argument to the article's claim.
#
# The revised version of the redesign can be seen [here]()
#
# *put screenshot and link *
#
# As it can be seen, the claim I am trying to make through the above graph is that- USA does not have that many guns compared to the population.
#
# My deceptive visualization supports my above-mentioned claim.
#
# A comparison between the original Vox article graph and my deceptive version is as follows : ##put screenshots
#
# **Data Cleaning:** The process I took to clean the data obtained from the data source is [here]() ##put link

# %% [markdown]
# ### GRAPH 3 :
#
# #### 3.1 Article View :
# The point the [article](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) makes for the 1st graph is : *"There have been more than 1,600 mass shootings since Sandy Hook"*.
#
# The graph from the article is as follows :
#
# ##put screenshot
#
# #### 3.2 MY VIEW :
# The graph shows the places where the mass shootings have occured since the Sandy Hook shooting incident. However, I think it would have been better to show the number of mass shootings, or the increase the mass shootings since then.
#
#
# **Data Source** : The data source is [this](http://www.gunviolencearchive.org/reports/mass-shooting).
#
# #### 3.2.1. REDESIGN VERSION
# My goal with the redesign is to that the number of mass shootings in USA have increased.
#
# The metrics I have used is the data of the year 2014 and 2017 to show the difference in the number of mass shootings that have happened.
#
#
# **First Version:** My first attempt to redesign the orginal visualization is as follows:
#
# ##put screen shot
#
# **Revised Version:** I improved upon the first version of the redesigned visualization shown above and redesigned it. I have compared the number of mass shootings in 2014 and 2017.
#
#
# The final revised version of the redesign can be seen [here]() ##put screen shot and link
#
# As it can be seen, the claim I am trying to make through the above graph is that- There has been an increase in the number of mass shootings that have happened since 2014.
#
# My backing and warrant come from all the mass shooting incidents that have happened in past 2 months itself.
#
# My redesigned visualization supports my above-mentioned claim.
#
# A comparison between the original Vox article graph and my redesiged version is as follows : ##put screenshots
#
# **Data Cleaning:** The process I took to clean the data obtained from the data source is [here]() ##put link

# %% [markdown]
# #### 3.2.2 DECEPTIVE VERSION:
#
# My goal with the deceptive version was to show that even though the article claims that the people affected due mass shootings has increased since the Sandy Hook incident in 2012, this number has risen in only a few states and for most of the states, the this number has not increased since 2016.
#
# **First Version:** My first attempt to develop a deceptive visualization is as follows:
#  ##put screenshot
#
# **Revised Version:** My revised version is the same as the first version, just a bit more polished. It meets my goal with the deceptive graph. Here I have taken the total number of people that are affected by the mass shootings to show my point.
#
# The revised version of the redesign can be seen [here]()
#
# *put screenshot and link *
#
# As it can be seen, the claim I am trying to make through the above graph is that-The number of mass shootings have not increased in all the states in the USA.
#
# My deceptive visualization supports my above-mentioned claim.
#
# My hypothesis/assumption is that all these states have atleast a few major cities with a large amount of population residing in them.
#
# A comparison between the original Vox article graph and my deceptive version is as follows : ##put screenshots
#
# **Data Cleaning:** The process I took to clean the data obtained from the data source is [here]() ##put link

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/datasets/GRAPH 3/chocolate_cake.jpg')  # choose image location

plt.imshow(image)
plt.show()
