# %% [markdown]
# ## MSIS 2629: Dashboards, Scorecard, and Visualization
# ### INDIVIDUAL PROJECT : REVISED VERSIONS
# ### AUTHOR : SALONI SHARMA
# **_____________________________________________________________________________________________________________________**

# %% [markdown]
# ### PREFACE :
#
# In this project, I take the graphs given in the [Vox article](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) **"America’s unique gun violence problem, explained in 17 maps and charts"** and attempt to substantially improve them as well as my previous versions.

# %% [markdown]
# ### INTRODUCTION :
#
# America is facing a gun violence problem and this holds true, even without collecting any facts, as seen from the shootings that have occurred in the past few months itself.
#
# The Vox article tries to analyze the gun-violence problem of the USA using graphs and charts, developed through data-sets obtained from various different sources.
#
# For my analysis, I have picked the first three graphs of the article.
#
# The graphs and their basic summaries are as follows:
#
# Graph 1: Number of firearm homicides
# > The first graph compares the number of firearm homicides in the USA with the rest of the world.
#
# Graph 2: Number of civilian-owned guns compared to the population
# > The second graph compares the population and the number of civilian-owned guns in the USA with other countries of the world.
#
# Graph 3: Mass Shootings
# > The third graph shows the change in the number of mass shootings in the USA since the Sandy Hook shooting in Dec 2012.
#
# My audience for this project would be the **General Public** or the common US population because I think it is the general public that needs to think and understand the implications of the wide and easy availability of firearms and their consequences.

# %% [markdown]
# ### GRAPH 1:
#
# #### 1.1 Article View :
# The point the [article](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) makes for the 1st graph is : *"America has six times as many firearm homicides as Canada, and nearly 16 times as many as Germany"*.
# It states that America leads the developed countries when it comes to firearm homicides.
#
# The graph from the article is as follows :

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/vox1.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# Source : https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts

# %% [markdown]
# #### 1.2 MY VIEW :
#
# According to me ,  a bar chart could put the point forward in a better way instead of the human-figurine graph.
#
# **Data Source** : The data source is [this](https://docs.google.com/spreadsheets/d/1chqUZHuY6cXYrRYkuE0uwXisGaYvr7durZHJhpLGycs/edit#gid=0)
#
# **Data Cleaning**: The data cleaning for the redesign and deceptiove versions can be seen [here](https://github.com/SaloniS95/DATA-VIZ-SPRING-2018-SCU/blob/master/g1_final%20version.ipynb)
#
# #### 1.2.1. REDESIGN VERSION
# My goal with the redesign is make the original graph look better, and to show that America owns a huge amount of guns compared to the other countries in the world.
#
# The metrics I have used is what is the number of civilian-owned guns in coutnries other than the USA.
#
# **First Version:** My first attempt to redesign the orginal visualization is as follows:

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g1_r1.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# **Revised Version:** I improved upon the first version of the redesigned visualization shown above and redesigned it.
# According to me, showing the comparisons of the countries mentioned in the article would be better to understand the point that the article was trying to make.
#
# So, I took the 14 countries included in the original visualization in the Vox article and compared them with each other.
#
# The revised version of the redeisgn can be seen [here](https://public.tableau.com/profile/saloni.sharma#!/vizhome/g1_14/g1_final_redesign?publish=yes)

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g1_redesign.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# As it can be seen, the claim I am trying to make through the above graph is that- The USA has extremely high number of firearm homicides compared to the developed countries in the world.
#
# My backing and warrant come from the data set itself which shows that the number is much higher in the USA than the other countries.
#
# My qualifier is that the comparison is only between the developed nations in the world and not *all* the countries in the world.
#
# My redesigned visualization supports my above-mentioned claim.
#
# The color is the standard Tableau colour and according to me, colours don't affect my argument, so I let this color be.

# %% [markdown]
# A comparison between the original Vox article graph and my redesiged version is as follows :

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/comp_r_g1.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# According to me, my redesigned version gives a clearer view of the situation of firearm homicides in the USA compared to other developed nations, than the vox article.

# %% [markdown]
# #### 1.2.2 DECEPTIVE VERSION:
#
# My goal with the deceptive version was to show that USA is *not* an outlier when it comes to firearm homicides, and that there are other countries in the world that precede it.
#
# My metric for this was how do other countries fare against the USA.
#
# **First Version:** My first attempt to develop a deceptive visualization is as follows:

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g1_d1.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# **Revised Version:** When I developed the ‘Redesign’ version of this chart, I found that in reality, USA is preceded by 4 other countries - Brazil, Colombia, Mexico and Venezuela in the number the firearm homicides. This graph shows the actual view of the situation each country of the world is in, in terms of firearm homicides.  It shows that USA is *not* the country with the highest number of firearm homicides in the world, like how the article implies. Brazil far exceeds the USA in this scenario.
#
# The revised version of the deceptive graph can be seen [here](https://public.tableau.com/profile/saloni.sharma#!/vizhome/g1_brazil/final_redesign?publish=yes)

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g1_decept.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# As it can be seen, the claim I am trying to make through the above graph is that- The USA is *not* a country with the highest number of firearm homicides. In terms of being an outlier, it is Brazil who takes the 1st place , and not USA.
# My deceptive visualization supports my above-mentioned claim.
#
# My backing and warrant come from the dataset that I obtained after cleaning that shows that Brazil has extremely high number of firearm homicides compared to the USA.
#
# My qualifier is that the comparison is now between all the countries of the world.
#
# The rebuttal to my graph would be that there are many countries that have extremely strict guns laws, whereas there are very few/liberal laws regarding guns and gun-ownership in few other countries. Other factors like how well developed a country is also affects the number of people who own guns. This graph is a good visual to get an overall picture of the firearm homicide scenario, but putting countries into certain bins would help us understand this situation better.
#
#
# The color is the standard Tableau colour and according to me, colours don't affect my argument, so I let this color be.
#
# A comparison between the original Vox article graph and my deceptive version is as follows :

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/comp_d_g1.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# My deceptive version negates the claim that the article is trying to make.

# %% [markdown]
# ### GRAPH 2 :
#
# #### 2.1 Article View :
# The point the [article](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) makes for the 1st graph is : *"America has 4.4 percent of the world’s population, but almost half of the civilian-owned guns around the world"*.
#
# The graph from the article is as follows :

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/vox2.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# Source : https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts

# %% [markdown]
# #### 2.2 MY VIEW :
# The original graph looks good but then, it does not make much sense, especially because the values are given in terms of percentages.
# In order to understand what the graph actually means, I did some calculations of my own, as follows -
#
# For the left hand side of the Graph : Population of the world
# * Population of the US = 4.43% of 7.13 Billion = 31.58 * 10^7
#
# For the right hand side of the Graph : Civilian owned guns in the world
# * Civilian owned guns in the US = 42% of 644 Million = 27.048 * 10^7
#
# From this, I calculated the percent of US population that owns guns :
# * Percent of Civilian owned guns = (Civilian owned guns in the USA / Population of the USA) * 100
# * Percent of Civilina owned guns = 85.6%
#
# **85.6% of US population owns guns. **
#
# So this is what the graph was trying to put forth.
#
#
# **Data Source** : The data source is [this](https://photius.com/rankings/population/population_2007_0.html) and [this](https://docs.google.com/spreadsheets/d/1chqUZHuY6cXYrRYkuE0uwXisGaYvr7durZHJhpLGycs/edit#gid=0).
#
# **Data Cleaning**: The data cleaning for the redesign and deceptiove versions can be seen [here](https://github.com/SaloniS95/DATA-VIZ-SPRING-2018-SCU/blob/master/g2_final.ipynb)The dataset from [Photius] ( https://photius.com/rankings/population/population_2007_0.html ) had to be first copied and pasted into notepad, from where I opened it in Excel selecting the "Delimited" and "Tab" as my criterias. Once the data opened in Excel, I gave the headers to the last 2 columns as “Country” and “Population” so that the analysis could become easier. The next steps of cleaning the data of the Excel file can be found in the link mentioned above.
#
# #### 2.2.1. REDESIGN VERSION
# My goal with the redesign is to show that almost 85% of the population of the USA owns guns.
#
# The metrics I used were the ratio of civilian-owned firearms to the population of the various countries in the world.
#
#
# **First Version:** My first attempt to redesign the orginal visualization is as follows:

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g2_r1.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# **Revised Version:** I improved upon the first version of the visualization shown above and redesigned it.
# I thought that it would be better to explore a few entities in the dataset like population, number of civilian owned guns, etc. through my revised version.
#
# I came up with 3 different redesign versions :
#
# Version 1:
#
# This graph compares the population and civilian owned firearms only in the USA. The heights of these bar graphs are very close to each other, showing that more than 50% of the population of the USA owns guns, which means that way too many people have firearms in this country, which is a bad news in itself, considering how gun violence is on the rise as the days go by.
#
#
# For this graph, I selected to keep only 'USA' in the Tableau worksheet. This graph is can be seen [here](https://public.tableau.com/profile/saloni.sharma#!/vizhome/g2_onlyusa/Dashboard1?publish=yes)

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g2_1_redesign.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# Version 2:
#
# This graph shows the comparison between USA and the rest of the countries in the world in terms of population and civilian owned firearms. This graph can be seen [here](https://public.tableau.com/profile/saloni.sharma#!/vizhome/g2_worldandusa/Dashboard1?publish=yes). As the article compared USA with the world, I decided to take the same path and tried to put USA against the cumulation of every other country in the world.

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g2_2_redesign.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# I felt that the above two graphs did not put forth my claim that well, so I went for a third redesign chart.
#
# This version is my Final Redesign version.
#
# Version 3:
#
# This graph effectively shows how high the percentage of firearms the USA has compared to the rest of the countries in the world. For ease, I have visualized only the top 10 countries with a high percentage of Civilian owned firearm to Total population ratio.
#
#
# The final revised version of the redesign can be seen [here](https://public.tableau.com/profile/saloni.sharma#!/vizhome/g2_percentdiff/Dashboard1?publish=yes)

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g2_3_redesign.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# As it can be seen, the claim I am trying to make through the above graph is that- More than 85% of the US population owns guns. This is far too much when compared to the rest of the countries.
#
# My redesigned visualization supports my above-mentioned claim.
#
# My backing and warrant come from the cleaned data set that clearly shows the stark difference in the percents for every country compared to the USA.
#
# The colour is the standard blue colour and it doesn't hinder my claim , so I let it be.
#
# A comparison between the original Vox article graph and my redesiged version is as follows :

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/comp_r_g2.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# Compared to the varied comparison shown in the original Vox article, I think my version gives a better understanding of how the US has a huge amoiunt of civilian-owned firearms.

# %% [markdown]
# #### 2.2.2 DECEPTIVE VERSION:
#
# My goal with the deceptive version was to show that USA does not have that many guns compared to the population.
#
# **Revised Version:** My revised version is the same as the first version because it deceives the audience into thinking that the number of firearms in the USA are not that high compared to the population.
#
# I developed a side-by-side bar chart to show the population and the average number of civilian owned firearms next to each other. What this does is that the Y axis has only 1 scale for the range, and because the actual total population is of the USA is more than the number of average number of civilian owned guns, it provides a counter argument to the article's claim.
#
# The revised version of the redesign can be seen [here](https://public.tableau.com/profile/saloni.sharma#!/vizhome/g2_decept_final/g2_deceptionmay18_1?publish=yes)

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g2_decept.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# As it can be seen, the claim I am trying to make through the above graph is that- USA does not have that many guns compared to the population.
#
# My deceptive visualization supports my above-mentioned claim.
#
# A comparison between the original Vox article graph and my deceptive version is as follows :

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/comp_d_g2.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# ### GRAPH 3 :
#
# #### 3.1 Article View :
# The point the [article](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) makes for the 1st graph is : *"There have been more than 1,600 mass shootings since Sandy Hook"*.
#
# The graph from the article is as follows :

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/vox3.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# Source : https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts

# %% [markdown]
# #### 3.2 MY VIEW :
# The graph shows the places where the mass shootings have occured since the Sandy Hook shooting incident. However, I think it would have been better to show the number of mass shootings, or the increase the mass shootings since then to support what the article claims.
#
#
# **Data Source** : The data source is [this](http://www.gunviolencearchive.org/reports/mass-shooting).
#
# **Data Cleaning**: The data cleaning for the redesign and deceptiove versions can be seen [here](https://github.com/SaloniS95/DATA-VIZ-SPRING-2018-SCU/blob/master/g3_final.ipynb)
#
# #### 3.2.1. REDESIGN VERSION
# My goal with the redesign is to show that the number of mass shootings in USA have increased.
#
# The metrics I have used is the data of the year 2014 and 2017 to show the difference in the number of mass shootings that have happened.
#
#
# **First Version:** My first attempt to redesign the orginal visualization is as follows:

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g3_r1.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# **Revised Version:** I improved upon the first version of the redesigned visualization shown above and redesigned it. I have compared the number of mass shootings in 2014 and 2017 only. My first version showed too much data, and for that reason. I decided to redesign it.
#
#
# The final revised version of the redesign can be seen [here](https://github.com/SaloniS95/DATA-VIZ-SPRING-2018-SCU/blob/master/g3_final.ipynb)

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g3_redesign.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# As it can be seen, the claim I am trying to make through the above graph is that- There has been an increase in the number of mass shootings that have happened since 2014.
#
# My backing and warrant come from all the mass shooting incidents that have happened in past several years.
#
# My redesigned visualization supports my above-mentioned claim.
#
# The qualifier is that, in the datasource, the way the "mass shooting" has been defined is very broad. Moreover, there are some mass shootings that go unreported, and hence this dataset might not include *all* of the mass shootings that have happened since the Sandy Hook incident.
#
# A comparison between the original Vox article graph and my redesiged version is as follows :

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/comp_r_g3.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# The original Vox article shows *where* the shootings have occured, rather than the increase in the number of mass shootings like my redesigned version does which supports the argument in a better way than the orginal Vox graph.

# %% [markdown]
# #### 3.2.2 DECEPTIVE VERSION:
#
# My goal with the deceptive version was to show that even though the article claims that the people affected due mass shootings has increased since the Sandy Hook incident in 2012, this number has risen in only a few states and for most of the states, the this number has not increased a lot.
#
# **Revised Version:** My revised version is the same as the first version. It meets my goal of the deceptive graph. Here I have taken the total number of people that are affected by the mass shootings to show my point.
#
# After finding the total number of people affected in 2014 and 2017, I found the mean of each. This graph consists of only those states for whom the Affected 2014 and Affected 2017 columns are above the average number in each of these columns.
#
# By changing the scale of the ‘Affected 2017’ data, the deceptive graph above shows that there has been a significant amount of decrease in the total number of affected people by mass shootings from 2014 to 2017, which is opposite to what the article states.
#
#
# The revised version of the redesign can be seen [here](https://public.tableau.com/profile/saloni.sharma#!/vizhome/g3final_deception2/g3_deception2_1?publish=yes)

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/g3_decept.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# As it can be seen, the claim I am trying to make through the above graph is that-The number of mass shootings have not increased in all the states in the USA.
#
# My deceptive visualization supports my above-mentioned claim.
#
# A comparison between the original Vox article graph and my deceptive version is as follows :

# %%
from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('C:/Users/salon/Desktop/scu/SPRING 2018/Data Viz/individual project/to use/comp_d_g3.png')  # choose image location

plt.imshow(image)
plt.show()

# %% [markdown]
# My deceptive graph negates the claim put forth by the article by showing that the total number of people affected by the mass shootings has reduced in most states except a few.
